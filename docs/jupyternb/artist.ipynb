# %% [markdown]
# # `Artist` class
# - class for exporting graphical schematics
#     - by default, figures are exported in `out` with designated file names

# %%
from tools import Artist

# %%
constructor = Artist()

# %% [markdown]
# ## `comparison_schematic`
# - file name: `comparison_schematic.png`

# %%
constructor.comparison_schematic()

# %% [markdown]
# ## `time_variation`
# - file name: `time_variation.png`

# %%
constructor.time_variation()

# %% [markdown]
# ## `analogical_schematic`
# - file name: `analogical_schematic`

# %%
constructor.analogical_schematic()

# %% [markdown]
# ## `pipeline`
# - pipeline func desined for `metapipeline`
# - arguments
#     - pipe: list (default:`artist_pipeline_adgile.keys()`)
#         - name of functins to call in the pipeline
#     - close: bool (default:False)
#         - pass True to close generated imgs
#     - adgile: bool (default:False)
#         - pass True to skip analyses for existing output files
# - return: `None`
# - output: generates output img files in the designated directory

# %%
# %time
constructor.pipeline(close=False)
# Out:
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 13.6 µs

# %%
# %time
constructor.pipeline(close=True, adgile=True)
# Out:
# CPU times: user 6 µs, sys: 3 µs, total: 9 µs
# Wall time: 11.2 µs
